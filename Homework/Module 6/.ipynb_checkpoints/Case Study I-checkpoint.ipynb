# %%
import pandas as pd
import numpy as np

# %%
dSet = pd.read_csv('prisoners.csv')

# %%
dSet
# Out:
#              STATE/UT  YEAR  \
# 0      Andhra Pradesh  2013
# 1   Arunachal Pradesh  2013
# 2               Assam  2013
# 3               Bihar  2013
# 4         Chhatisgarh  2013
# 5                 Goa  2013
# 6             Gujarat  2013
# 7             Haryana  2013
# 8    Himachal Pradesh  2013
# 9     Jammu & Kashmir  2013
# 10          Jharkhand  2013
# 11          Karnataka  2013
# 12             Kerala  2013
# 13     Madhya Pradesh  2013
# 14        Maharashtra  2013
# 15            Manipur  2013
# 16          Meghalaya  2013
# 17            Mizoram  2013
# 18           Nagaland  2013
# 19             Orissa  2013
# 20             Punjab  2013
# 21          Rajasthan  2013
# 22             Sikkim  2013
# 23          Tamilnadu  2013
# 24            Tripura  2013
# 25      Uttar Pradesh  2013
# 26        Uttaranchal  2013
# 27        West Bengal  2013
# 28      A & N Islands  2013
# 29         Chandigarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# ...

# %%
dSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 6 columns):
# STATE/UT                                             35 non-null object
# YEAR                                                 35 non-null int64
# No. of Inmates benefitted by Elementary Education    35 non-null int64
# No. of Inmates benefitted by Adult Education         35 non-null int64
# No. of Inmates benefitted by Higher Education        35 non-null int64
# No. of Inmates benefitted by Computer Course         35 non-null int64
# dtypes: int64(5), object(1)
# memory usage: 1.7+ KB

# %%
dSet['total_benefitted'] = dSet.values[:,2:6].sum(axis=1)

# %%
total = dSet.values[:,2:6].sum(axis=0)
