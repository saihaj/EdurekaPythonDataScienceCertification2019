# %%
import numpy as np
import pandas as pd

# %%
SalesData = pd.read_csv('BigMartSalesData.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
SalesData2011 = SalesData[SalesData['Year']==2011]
x2011 = SalesData2011['Month']
y2011 = SalesData2011['Amount']

# %%
sns.scatterplot(x2011,y2011)

# %%
sns.barplot(data=SalesData2011, x='Month',y='Amount')

# %%
amount = SalesData['Amount']
quantity = SalesData['Quantity']

# %%
sns.scatterplot(quantity,amount)
