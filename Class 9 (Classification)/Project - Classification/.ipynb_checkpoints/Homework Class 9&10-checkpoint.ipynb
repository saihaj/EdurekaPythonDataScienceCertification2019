# %%
#2:37
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Train_Dataset = pd.read_csv('Python_Module_Day_15.2_Credit_Risk_Train_data_XTRAIN.csv')

# %%
Train_Dataset
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
# Replace Y = 1 and N =0
# Replace Graduate = 1 and Not Graduate = 0
Train_Dataset = Train_Dataset.replace(['Y','N'],(1,0))
Train_Dataset = Train_Dataset.replace(['Yes','No'],(1,0))
Train_Dataset = Train_Dataset.replace(['Graduate','Not Graduate'],(1,0))

# %%
Train_Dataset.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
sns.boxplot(data=Train_Dataset, y ='LoanAmount')

# %%
sns.boxplot(data=Train_Dataset, y='Loan_Amount_Term')

# %%
sns.boxplot(data=Train_Dataset, y='Credit_History')

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values='NaN', strategy='median', axis = 0)
imputer = imputer.fit(Train_Dataset.iloc[:,8:11])
Train_Dataset.iloc[:,8:11] = imputer.transform(Train_Dataset.iloc[:,8:11])
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(strategy='most_frequent')
Train_Dataset.iloc[:,1:4] =  imp.fit_transform(Train_Dataset.iloc[:,1:4])

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(strategy='most_frequent')
Train_Dataset.iloc[:,5:6] =  imp.fit_transform(Train_Dataset.iloc[:,5:6])

# %%
xTrainDataset = Train_Dataset.iloc[:,[2,4,5,6,7,8,9,10]].values

# %%
yTrainDataset = Train_Dataset.iloc[:,12].values

# %% [markdown]
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# xTrainDataset = sc.fit_transform(xTrainDataset)

# %%
Test_Dataset = pd.read_csv('Python_Module_Day_15.3_Credit_Risk_Test_data.csv')

# %%
Test_Dataset.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
sns.boxplot(data=Test_Dataset, y ='LoanAmount')

# %%
sns.boxplot(data=Test_Dataset, y ='Loan_Amount_Term')

# %%
sns.boxplot(data=Test_Dataset, y ='Credit_History')

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values='NaN', strategy='median', axis = 0)
imputer = imputer.fit(Test_Dataset.iloc[:,8:11])
Test_Dataset.iloc[:,8:11] = imputer.transform(Test_Dataset.iloc[:,8:11])
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(strategy='most_frequent')
Test_Dataset.iloc[:,1:4] =  imp.fit_transform(Test_Dataset.iloc[:,1:4])

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(strategy='most_frequent')
Test_Dataset.iloc[:,5:6] =  imp.fit_transform(Test_Dataset.iloc[:,5:6])

# %%
# Replace Y = 1 and N =0
# Replace Graduate = 1 and Not Graduate = 0
Test_Dataset = Test_Dataset.replace(['Y','N'],(1,0))
Test_Dataset = Test_Dataset.replace(['Yes','No'],(1,0))
Test_Dataset = Test_Dataset.replace(['Graduate','Not Graduate'],(1,0))

# %%
xTestDataset = Test_Dataset.iloc[:,[2,4,5,6,7,8,9,10]].values

# %%
Train_Dataset.to_csv('CleanedTrainDataset.csv')

# %%
Test_Dataset.to_csv('CleanedTestDataset.csv')

# %%
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()
logmodel.fit(xTrainDataset,yTrainDataset)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred = logmodel.predict(xTrainDataset)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(yTrainDataset,y_pred)
print('accuracy %s' % accuracy_score(yTrainDataset, y_pred))
# Out:
# accuracy 0.8110749185667753

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski',p=2)
knn.fit(xTrainDataset,yTrainDataset)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
y_pred = knn.predict(xTrainDataset)
print('accuracy %s' % accuracy_score(yTrainDataset, y_pred))
# Out:
# accuracy 0.7296416938110749

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(xTrainDataset,yTrainDataset)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred = nb.predict(xTrainDataset)
print('accuracy %s' % accuracy_score(yTrainDataset, y_pred))
# Out:
# accuracy 0.7996742671009772
