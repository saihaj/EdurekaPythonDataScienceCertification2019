# %%
import os
os.chdir('D:\\Edureka\\Jun 1 - Edureka - Python\\Class 13 - Codes\\')

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('airline_passengers.csv')

# %%
dataset
# Out:
#        Month  Thousands of Passengers
# 0    1949-01                      112
# 1    1949-02                      118
# 2    1949-03                      132
# 3    1949-04                      129
# 4    1949-05                      121
# 5    1949-06                      135
# 6    1949-07                      148
# 7    1949-08                      148
# 8    1949-09                      136
# 9    1949-10                      119
# 10   1949-11                      104
# 11   1949-12                      118
# 12   1950-01                      115
# 13   1950-02                      126
# 14   1950-03                      141
# 15   1950-04                      135
# 16   1950-05                      125
# 17   1950-06                      149
# 18   1950-07                      170
# 19   1950-08                      170
# 20   1950-09                      158
# 21   1950-10                      133
# 22   1950-11                      114
# 23   1950-12                      140
# ...

# %%
dataset['Month'] = pd.to_datetime(dataset['Month'])

# %%
dataset.set_index('Month', inplace=True)

# %%
dataset.plot()

# %%
timeseries  =  dataset['Thousands of Passengers']

# %%
type(timeseries)
# Out:
# pandas.core.series.Series

# %%
timeseries.rolling(12).mean().plot()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(dataset['Thousands of Passengers'], freq=12)
decomposition.plot()

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(dataset['Thousands of Passengers'])
# Out:
# (0.8153688792060423,
#  0.9918802434376409,
#  13,
#  130,
#  {'1%': -3.4816817173418295,
#   '5%': -2.8840418343195267,
#   '10%': -2.578770059171598},
#  996.6929308390189)

# %%
def adf_check(time_series):
    result = adfuller(time_series)
    print('Augmented Dickey Fuller Test')
    labels = ['ADF Test Statistic', 'P-value', ' #Lags used', ' No of obs']
    
    for value, label in zip(result, labels):
        print(label + ' : '+str(value))
        
    if result[1]<=0.05:
        print('Strong evidence against null hypothesis and my time series is stationary')
    else:
        print('weak evidence against null hypothesis and my time series is non stationary')

# %%
adf_check(dataset['Thousands of Passengers'])
# Out:
# Augmented Dickey Fuller Test
# ADF Test Statistic : 0.8153688792060423
# P-value : 0.9918802434376409
#  #Lags used : 13
#  No of obs : 130
# weak evidence against null hypothesis and my time series is non stationary

# %%
dataset['Thousands of Passengers First Diff'] = dataset['Thousands of Passengers'] - dataset['Thousands of Passengers'].shift(1)

# %%
dataset
# Out:
#             Thousands of Passengers  Thousands of Passengers First Diff
# Month
# 1949-01-01                      112                                 NaN
# 1949-02-01                      118                                 6.0
# 1949-03-01                      132                                14.0
# 1949-04-01                      129                                -3.0
# 1949-05-01                      121                                -8.0
# 1949-06-01                      135                                14.0
# 1949-07-01                      148                                13.0
# 1949-08-01                      148                                 0.0
# 1949-09-01                      136                               -12.0
# 1949-10-01                      119                               -17.0
# 1949-11-01                      104                               -15.0
# 1949-12-01                      118                                14.0
# ...

# %%
adf_check(dataset['Thousands of Passengers First Diff'].dropna())
# Out:
# Augmented Dickey Fuller Test
# ADF Test Statistic : -2.8292668241699874
# P-value : 0.05421329028382711
#  #Lags used : 12
#  No of obs : 130
# weak evidence against null hypothesis and my time series is non stationary

# %%
dataset['Thousands of Passengers First Diff'].plot()

# %%
dataset['Thousands of Passengers 2nd Diff'] = dataset['Thousands of Passengers First Diff'] - dataset['Thousands of Passengers First Diff'].shift(1)

# %%
dataset
# Out:
#             Thousands of Passengers  Thousands of Passengers First Diff  \
# Month
# 1949-01-01                      112                                 NaN
# 1949-02-01                      118                                 6.0
# 1949-03-01                      132                                14.0
# 1949-04-01                      129                                -3.0
# 1949-05-01                      121                                -8.0
# 1949-06-01                      135                                14.0
# 1949-07-01                      148                                13.0
# 1949-08-01                      148                                 0.0
# 1949-09-01                      136                               -12.0
# 1949-10-01                      119                               -17.0
# 1949-11-01                      104                               -15.0
# 1949-12-01                      118                                14.0
# ...

# %%
adf_check(dataset['Thousands of Passengers 2nd Diff'].dropna())
# Out:
# Augmented Dickey Fuller Test
# ADF Test Statistic : -16.384231542468513
# P-value : 2.7328918500142026e-29
#  #Lags used : 11
#  No of obs : 130
# Strong evidence against null hypothesis and my time series is stationary

# %%
dataset['Thousands of Passengers 2nd Diff'].plot()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(dataset['Thousands of Passengers 2nd Diff'].dropna(), lags=14)
#p=0

# %%
len(dataset)
# Out:
# 144

# %%
plot_pacf(dataset['Thousands of Passengers 2nd Diff'].dropna(), lags=14)
#q=0
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1283: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
import statsmodels.api as sm

# %%
model = sm.tsa.statespace.SARIMAX(dataset['Thousands of Passengers'], order=(0,2,0), seasonal_order=(1,2,1,12))

# %%
results = model.fit()

# %%
print(results.summary())
# Out:
#                                  Statespace Model Results
# ...
# Dep. Variable:            Thousands of Passengers   No. Observations:                  144
# Model:             SARIMAX(0, 2, 0)x(1, 2, 1, 12)   Log Likelihood                -536.009
# Date:                            Sat, 13 Jul 2019   AIC                           1078.018
# Time:                                    23:08:29   BIC                           1086.330
# Sample:                                01-01-1949   HQIC                          1081.393
#                                      - 12-01-1960
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12      -0.1960      0.139     -1.413      0.158      -0.468       0.076
# ma.S.L12      -0.9979     15.480     -0.064      0.949     -31.339      29.343
# ...

# %%
dataset['forecast'] = results.predict(start=130, end = 144, dynamic=True)
dataset[['Thousands of Passengers', 'forecast']].plot()

# %%
AR (p), I (d), MA (q)
